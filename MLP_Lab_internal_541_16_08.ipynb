# %% [markdown]
# ##Question no. 8

# %% [markdown]
# ###Program to implement pandas library for creating series, dataframe, panel and split dataframe into 50:50 as training data and testing data

# %%
import pandas as pd
x=pd.Series(data=["Ram","Ian","Vijay","Karthik","James","Paul"],index=[1,2,3,4,5,6])
print(x)
print(type(x))
# Out:
# 1        Ram
# 2        Ian
# 3      Vijay
# 4    Karthik
# 5      James
# 6       Paul
# dtype: object
# <class 'pandas.core.series.Series'>

# %%
z=pd.DataFrame(x)
z
# Out:
#          0
# 1      Ram
# 2      Ian
# 3    Vijay
# 4  Karthik
# 5    James
# 6     Paul

# %%
x=[{"s.no":1,"name":"Priyanka","rollno":41},{"s.no":2,"name":"sravya","rollno":58},{"s.no":3,"name":"Snigdha","rollno":21},{"s.no":4,"name":"Ashritha","rollno":33}
   ]
df=pd.DataFrame(x)
df
# Out:
#    s.no      name  rollno
# 0     1  Priyanka      41
# 1     2    sravya      58
# 2     3   Snigdha      21
# 3     4  Ashritha      33

# %%
df.shape
# Out:
# (4, 3)

# %%
y=[{"s.no":1,"name":"Shoyab","rollno":32},{"s.no":2,"name":"akash","rollno":56},{"s.no":3,"name":"sajid","rollno":46},{"s.no":4,"name":"yashwanth","rollno":55}
   ]
df1=pd.DataFrame(y)
df1
# Out:
#    s.no       name  rollno
# 0     1     Shoyab      32
# 1     2      akash      56
# 2     3      sajid      46
# 3     4  yashwanth      55

# %%
df1.shape
# Out:
# (4, 3)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df,df1,test_size=0.2,random_state=1)

# %%
x_train.shape,y_train.shape
# Out:
# ((3, 3), (3, 3))

# %%
x_test.shape,x_test.shape
# Out:
# ((1, 3), (1, 3))

# %%
import numpy as np
x=np.random.random(1000).reshape(100,10)
x
# Out:
# array([[2.96305627e-01, 5.80750791e-02, 5.33928729e-01, 6.21091942e-02,
#         8.10766372e-02, 5.08211621e-01, 3.96660052e-01, 2.14624828e-01,
#         1.24807477e-02, 1.97575584e-01],
#        [4.83204924e-01, 2.28213730e-02, 2.41562066e-01, 8.13597785e-02,
#         8.11430093e-01, 4.27353530e-01, 7.20538776e-01, 1.60264634e-01,
#         1.27684645e-01, 5.56864735e-01],
#        [9.88580681e-02, 4.32322090e-01, 5.53950808e-01, 4.19107730e-01,
#         8.41383886e-01, 8.01760380e-01, 3.55530513e-01, 4.99304427e-01,
#         7.71957179e-02, 4.81371635e-01],
#        [3.14413853e-01, 3.65553503e-01, 9.80258080e-01, 3.07977825e-01,
#         7.41507563e-01, 5.65253677e-01, 2.49035879e-01, 5.16704454e-01,
#         1.74959159e-01, 9.46373478e-01],
#        [8.92688677e-01, 7.06115661e-01, 5.04952249e-01, 7.18964000e-01,
#         1.07413177e-01, 4.88975471e-01, 9.29251492e-01, 4.27924347e-01,
#         2.32723165e-01, 6.90059866e-02],
# ...

# %%
y=np.random.random(1000).reshape(100,10)
y
# Out:
# array([[0.32560915, 0.92137478, 0.41423921, 0.45369573, 0.61937482,
#         0.07328921, 0.55315215, 0.36699595, 0.37007611, 0.8515265 ],
#        [0.19679416, 0.80277885, 0.69402388, 0.07924965, 0.90136026,
#         0.17928958, 0.25672587, 0.1696111 , 0.73332465, 0.71443387],
#        [0.81976224, 0.54822092, 0.23878157, 0.7330854 , 0.45740912,
#         0.92654488, 0.86287607, 0.91543736, 0.37364001, 0.60864904],
#        [0.70748161, 0.76562796, 0.64599402, 0.79593425, 0.11191513,
#         0.33300107, 0.20972475, 0.01674162, 0.11892299, 0.95566442],
#        [0.66840004, 0.64053607, 0.25089742, 0.06362456, 0.2612301 ,
#         0.46065821, 0.45587492, 0.97948378, 0.32216447, 0.59493283],
#        [0.62576873, 0.88623517, 0.0265974 , 0.06883385, 0.85682858,
#         0.91774895, 0.15401816, 0.23020113, 0.50350007, 0.47448451],
#        [0.84768848, 0.09445509, 0.4819448 , 0.32707699, 0.25535275,
#         0.30663978, 0.44422515, 0.57394539, 0.02857294, 0.10746962],
# ...

# %%
df=pd.DataFrame(x)
df
# Out:
#            0         1         2  ...         7         8         9
# 0   0.296306  0.058075  0.533929  ...  0.214625  0.012481  0.197576
# 1   0.483205  0.022821  0.241562  ...  0.160265  0.127685  0.556865
# 2   0.098858  0.432322  0.553951  ...  0.499304  0.077196  0.481372
# 3   0.314414  0.365554  0.980258  ...  0.516704  0.174959  0.946373
# 4   0.892689  0.706116  0.504952  ...  0.427924  0.232723  0.069006
# ..       ...       ...       ...  ...       ...       ...       ...
# 95  0.021931  0.478218  0.027465  ...  0.582803  0.003304  0.506175
# 96  0.798735  0.029599  0.095929  ...  0.834376  0.997145  0.904570
# 97  0.865119  0.515673  0.314942  ...  0.452289  0.077025  0.509015
# 98  0.167667  0.430545  0.917288  ...  0.940668  0.811676  0.164291
# 99  0.919558  0.252771  0.534678  ...  0.623572  0.933786  0.223584
#
# [100 rows x 10 columns]

# %%
df1=pd.DataFrame(y)
df1
# Out:
#            0         1         2  ...         7         8         9
# 0   0.325609  0.921375  0.414239  ...  0.366996  0.370076  0.851526
# 1   0.196794  0.802779  0.694024  ...  0.169611  0.733325  0.714434
# 2   0.819762  0.548221  0.238782  ...  0.915437  0.373640  0.608649
# 3   0.707482  0.765628  0.645994  ...  0.016742  0.118923  0.955664
# 4   0.668400  0.640536  0.250897  ...  0.979484  0.322164  0.594933
# ..       ...       ...       ...  ...       ...       ...       ...
# 95  0.768095  0.519626  0.642771  ...  0.548938  0.223357  0.626710
# 96  0.386287  0.327569  0.141112  ...  0.351448  0.488551  0.174807
# 97  0.573152  0.476886  0.795626  ...  0.430104  0.241316  0.383458
# 98  0.475948  0.481342  0.115949  ...  0.971132  0.607285  0.094006
# 99  0.463159  0.285261  0.681324  ...  0.324354  0.794005  0.456592
#
# [100 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df,df1,test_size=0.5,random_state=1)

# %%
x_train.shape,y_train.shape
# Out:
# ((50, 10), (50, 10))

# %%
x_test.shape,y_test.shape
# Out:
# ((50, 10), (50, 10))
